# %%
import numpy as np
import pandas as pd
import glob

# SQLAlchemy
from sqlalchemy import create_engine
from config import db_password

# %% [markdown]
# **Clean players' info**

# %%
# file path changed to model/file_name.csv 
file_path = "new_matches.csv"

df = pd.read_csv(file_path)
df.head(5)
# Out:
#   tourney_id      tourney_name surface  draw_size tourney_level tourney_date  \
# 0   1968-580  Australian Chps.   Grass         64             G   1968-01-19
# 1   1968-580  Australian Chps.   Grass         64             G   1968-01-19
# 2   1968-580  Australian Chps.   Grass         64             G   1968-01-19
# 3   1968-580  Australian Chps.   Grass         64             G   1968-01-19
# 4   1968-580  Australian Chps.   Grass         64             G   1968-01-19
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0         48     100101         12.0          NaN  ...     NaN      NaN
# 1         26     100110          NaN          NaN  ...     NaN      NaN
# 2         25     100169          NaN          NaN  ...     NaN      NaN
# 3         24     100090          4.0          NaN  ...     NaN      NaN
# 4         23     100106         11.0          NaN  ...     NaN      NaN
#
# ...

# %%
df.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points'],
#       dtype='object')

# %% [markdown]
# **winners**

# %%
w_df = df[['winner_id','winner_name', 'winner_hand', 'winner_ht'
           , 'winner_ioc', 'winner_age','winner_rank','winner_rank_points']]
w_df
# Out:
#         winner_id      winner_name winner_hand  winner_ht winner_ioc  \
# 0          100101      Mike Belkin           R        NaN        CAN
# 1          100110    Terry Addison           R      180.0        AUS
# 2          100169     Ian Fletcher           R        NaN        AUS
# 3          100090      Dick Crealy           R        NaN        AUS
# 4          100106  Graham Stilwell           R      173.0        GBR
# ...           ...              ...         ...        ...        ...
# 180300     127339       Borna Gojo           R        NaN        CRO
# 180301     126094    Andrey Rublev           R      188.0        RUS
# 180302     106421  Daniil Medvedev           R      198.0        RUS
# 180303     126094    Andrey Rublev           R      188.0        RUS
# 180304     106421  Daniil Medvedev           R      198.0        RUS
#
#         winner_age  winner_rank  winner_rank_points
# 0        22.557153          NaN                 NaN
# ...

# %%
w_df2 = w_df.rename(columns={"winner_id": "player_id",
                            "winner_name": "player_name",
                            "winner_hand": "player_hand",
                            "winner_ht": "player_ht",
                            "winner_ioc": "player_ioc",
                            "winner_age": "player_age",
                            "winner_rank" : "player_rank",
                            "winner_rank_points": "player_rank_points"} )
w_df2
# Out:
#         player_id      player_name player_hand  player_ht player_ioc  \
# 0          100101      Mike Belkin           R        NaN        CAN
# 1          100110    Terry Addison           R      180.0        AUS
# 2          100169     Ian Fletcher           R        NaN        AUS
# 3          100090      Dick Crealy           R        NaN        AUS
# 4          100106  Graham Stilwell           R      173.0        GBR
# ...           ...              ...         ...        ...        ...
# 180300     127339       Borna Gojo           R        NaN        CRO
# 180301     126094    Andrey Rublev           R      188.0        RUS
# 180302     106421  Daniil Medvedev           R      198.0        RUS
# 180303     126094    Andrey Rublev           R      188.0        RUS
# 180304     106421  Daniil Medvedev           R      198.0        RUS
#
#         player_age  player_rank  player_rank_points
# 0        22.557153          NaN                 NaN
# ...

# %% [markdown]
# **loser**

# %%
l_df = df[['loser_id', 'loser_name', 'loser_hand','loser_ht', 'loser_ioc', 'loser_age','loser_rank','loser_rank_points']]
l_df
# Out:
#         loser_id          loser_name loser_hand  loser_ht loser_ioc  \
# 0         100105         Allan Stone          R       NaN       AUS
# 1         110045       Peter Mockler          R       NaN       IRL
# 2         100201            Syd Ball          R     188.0       AUS
# 3         110044            O Worley          R       NaN       AUS
# 4         110043        Gavin Hogben          R       NaN       AUS
# ...          ...                 ...        ...       ...       ...
# 180300    105583       Dusan Lajovic          R     180.0       SRB
# 180301    136440     Dominik Koepfer          L     180.0       GER
# 180302    105526  Jan Lennard Struff          R     193.0       GER
# 180303    127339          Borna Gojo          R       NaN       CRO
# 180304    105227         Marin Cilic          R     198.0       CRO
#
#         loser_age  loser_rank  loser_rank_points
# 0       22.264203         NaN                NaN
# 1             NaN         NaN                NaN
# ...

# %%
l_df2 = l_df.rename(columns={"loser_id": "player_id",
                            "loser_name": "player_name",
                            "loser_hand": "player_hand",
                            "loser_ht": "player_ht",
                            "loser_ioc": "player_ioc",
                            "loser_age": "player_age",
                            "loser_rank":"player_rank",
                            "loser_rank_points":"player_rank_points"})
l_df2
# Out:
#         player_id         player_name player_hand  player_ht player_ioc  \
# 0          100105         Allan Stone           R        NaN        AUS
# 1          110045       Peter Mockler           R        NaN        IRL
# 2          100201            Syd Ball           R      188.0        AUS
# 3          110044            O Worley           R        NaN        AUS
# 4          110043        Gavin Hogben           R        NaN        AUS
# ...           ...                 ...         ...        ...        ...
# 180300     105583       Dusan Lajovic           R      180.0        SRB
# 180301     136440     Dominik Koepfer           L      180.0        GER
# 180302     105526  Jan Lennard Struff           R      193.0        GER
# 180303     127339          Borna Gojo           R        NaN        CRO
# 180304     105227         Marin Cilic           R      198.0        CRO
#
#         player_age  player_rank  player_rank_points
# ...

# %%
all_players = pd.concat([w_df2, l_df2], axis = 0)
all_players
# Out:
#         player_id         player_name player_hand  player_ht player_ioc  \
# 0          100101         Mike Belkin           R        NaN        CAN
# 1          100110       Terry Addison           R      180.0        AUS
# 2          100169        Ian Fletcher           R        NaN        AUS
# 3          100090         Dick Crealy           R        NaN        AUS
# 4          100106     Graham Stilwell           R      173.0        GBR
# ...           ...                 ...         ...        ...        ...
# 180300     105583       Dusan Lajovic           R      180.0        SRB
# 180301     136440     Dominik Koepfer           L      180.0        GER
# 180302     105526  Jan Lennard Struff           R      193.0        GER
# 180303     127339          Borna Gojo           R        NaN        CRO
# 180304     105227         Marin Cilic           R      198.0        CRO
#
#         player_age  player_rank  player_rank_points
# ...

# %%
all_players['player_age'] = round(all_players['player_age'])
all_players
# Out:
#         player_id         player_name player_hand  player_ht player_ioc  \
# 0          100101         Mike Belkin           R        NaN        CAN
# 1          100110       Terry Addison           R      180.0        AUS
# 2          100169        Ian Fletcher           R        NaN        AUS
# 3          100090         Dick Crealy           R        NaN        AUS
# 4          100106     Graham Stilwell           R      173.0        GBR
# ...           ...                 ...         ...        ...        ...
# 180300     105583       Dusan Lajovic           R      180.0        SRB
# 180301     136440     Dominik Koepfer           L      180.0        GER
# 180302     105526  Jan Lennard Struff           R      193.0        GER
# 180303     127339          Borna Gojo           R        NaN        CRO
# 180304     105227         Marin Cilic           R      198.0        CRO
#
#         player_age  player_rank  player_rank_points
# ...

# %%
all_players.isnull().sum()
# Out:
# player_id                  0
# player_name                0
# player_hand              201
# player_ht              49838
# player_ioc                63
# player_age              7692
# player_rank            75586
# player_rank_points    156078
# dtype: int64

# %%
all_players.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 180300     True
# 180301     True
# 180302     True
# 180303     True
# 180304     True
# Length: 360610, dtype: bool

# %%
all_players.shape
# Out:
# (360610, 8)

# %%
all_players1 = all_players.sort_values('player_age', ascending=False).drop_duplicates('player_id').sort_index()
all_players1
# Out:
#         player_id         player_name player_hand  player_ht player_ioc  \
# 1          110045       Peter Mockler           R        NaN        IRL
# 3          110044            O Worley           R        NaN        AUS
# 4          110043        Gavin Hogben           R        NaN        AUS
# 5          107383         John Fraser           R        NaN        AUS
# 5          110042        Neal Higgins           R        NaN        AUS
# ...           ...                 ...         ...        ...        ...
# 180289     105526  Jan Lennard Struff           R      193.0        GER
# 180292     132283      Lorenzo Sonego           R      191.0        ITA
# 180297     111200          Elias Ymer           R      183.0        SWE
# 180303     127339          Borna Gojo           R        NaN        CRO
# 180304     105227         Marin Cilic           R      198.0        CRO
#
#         player_age  player_rank  player_rank_points
# ...

# %%
all_players1.shape
# Out:
# (6490, 8)

# %%
all_players1.fillna('Information Not Available', inplace=True)
all_players1.sample(10)
# Out:
#         player_id            player_name player_hand  \
# 32803      100262           Rolf Norberg           R
# 167889     145003  Lucas Andriamasilalao           R
# 43562      100308         Robert Trogolo           R
# 169886     144972   Geoffrey Blancaneaux           R
# 70213      100669        Charles Bud Cox           R
# 132869     104951         Aljoscha Thron           R
# 139491     104464   Abdul Mumin Babalola           L
# 117324     103400  Hendri Susilo Pramono           R
# 122371     101957            Milen Velev           R
# 45464      106447        Adolfo Gonzalez           R
#
#                         player_ht player_ioc                 player_age  \
# 32803   Information Not Available        SWE                       26.0
# 167889  Information Not Available        MAD                       20.0
# 43562                       180.0        RSA                       27.0
# 169886  Information Not Available        FRA                       19.0
# ...

# %%
all_players1.sort_values('player_name', ascending=True, inplace=True)
all_players1.sample(10)
# Out:
#         player_id            player_name player_hand  \
# 82853      110892         Katore Agnamba           U
# 179241     105539         Evgeny Donskoy           R
# 27072      100065             Terry Ryan           R
# 96155      102378        Juan Gisbert Jr           R
# 84620      108235          Sergej Skakun           R
# 75677      100931          Andrew Burrow           R
# 15035      209807        Andreas Trenkle           U
# 180143     105732  Pierre Hugues Herbert           R
# 24746      100304          Robert Kreiss           R
# 78696      108159           Rohit Rajpal           R
#
#                         player_ht                 player_ioc  \
# 82853   Information Not Available                        TOG
# 179241                      185.0                        RUS
# 27072   Information Not Available                        RSA
# 96155                       198.0                        ESP
# 84620   Information Not Available                        RUS
# ...

# %%
all_players1.isnull().sum()
# Out:
# player_id             0
# player_name           0
# player_hand           0
# player_ht             0
# player_ioc            0
# player_age            0
# player_rank           0
# player_rank_points    0
# dtype: int64

# %% [markdown]
# ### new_rankings

# %%
file_path = "new_rankings.csv"

rankings_df = pd.read_csv(file_path)
rankings_df.head(5)
# Out:
#   ranking_date  rank  player  points
# 0   1973-08-27    63  100286     NaN
# 1   1973-08-27    55  100219     NaN
# 2   1973-08-27    26  100220     NaN
# 3   1973-08-27   130  100223     NaN
# 4   1973-08-27    25  100229     NaN

# %%
rankings = rankings_df.rename(columns={"player": "player_id"})
rankings
# Out:
#         ranking_date  rank  player_id  points
# 0         1973-08-27    63     100286     NaN
# 1         1973-08-27    55     100219     NaN
# 2         1973-08-27    26     100220     NaN
# 3         1973-08-27   130     100223     NaN
# 4         1973-08-27    25     100229     NaN
# ...              ...   ...        ...     ...
# 3037661   2022-03-07  1265     210281     5.0
# 3037662   2022-03-07  1264     208389     5.0
# 3037663   2022-03-07  1262     202088     5.0
# 3037664   2022-03-07   900     106360    17.0
# 3037665   2022-03-07   899     209898    17.0
#
# [3037666 rows x 4 columns]

# %% [markdown]
# ### Merge players and rankings:
# `all_players1` and `rankings` on `player_id`
# We want Player Names on Rankings info

# %%
all_player2 = all_players[['player_id','player_name']]
all_player2 =  all_player2.drop_duplicates()
all_player2.index = range(all_player2.shape[0])
all_player2
# Out:
#       player_id      player_name
# 0        100101      Mike Belkin
# 1        100110    Terry Addison
# 2        100169     Ian Fletcher
# 3        100090      Dick Crealy
# 4        100106  Graham Stilwell
# ...         ...              ...
# 6485     120270   Edgars Manusis
# 6486     209147    Vilius Gaubas
# 6487     209863         Leo Borg
# 6488     208122      Thabo Ncube
# 6489     206681  Fabian Marozsan
#
# [6490 rows x 2 columns]

# %%
pen = pd.merge(rankings,all_player2, left_on="player_id",right_on='player_id')

# %%
pen.sort_values(by='ranking_date')
# Out:
#         ranking_date  rank  player_id  points                      player_name
# 0         1973-08-27    63     100286     NaN                   Harold Solomon
# 9652      1973-08-27   156     108360     NaN                Teimuraz Kakoulia
# 13951     1973-08-27    29     100437     NaN                       Bjorn Borg
# 16984     1973-08-27   126     100027     NaN                       Gene Scott
# 9677      1973-08-27   149     108407     NaN                  Tom Christensen
# ...              ...   ...        ...     ...                              ...
# 1197552   2022-03-07   599     105064    46.0                  Thomaz Bellucci
# 1081651   2022-03-07   301     104719   161.0                Marcel Granollers
# 1510154   2022-03-07   426     126939    89.0                 Khumoun Sultanov
# 1510475   2022-03-07   485     117365    69.0                Petros Chrysochos
# 1559904   2022-03-07  1234     209871     6.0  Amr Elsayed Abdou Ahmed Mohamed
#
# ...

# %%
#pen.to_csv("rankings_names.csv", index=False,header=True)

# %% [markdown]
# ### Connection to postgreSQL with SQLAlchemy

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/tennis_project"

# %%
# database engine
engine = create_engine(db_string)

# %% [markdown]
# #1

# %%
#pen.to_sql(name='player_ranking', con=engine)

# %%
# this should be the final merge minus some cols
#pen.sample(10)

# %% [markdown]
# #2

# %%
all_players1.to_sql(name='all_players', con=engine)

# %%
#all_players1.sample(10)

# %% [markdown]
# #3

# %%
rankings.to_sql(name='rankings', con=engine)

# %%
#rankings.sample(10)

# %% [markdown]
# ### Convert To JSON

# %%
#newdf = df.to_json(orient="records")
#newdf
